# %% [markdown]
#  # Quick example for PtyRAD
#
#  Chia-Hao Lee
#
# cl2696@cornell.edu
#
# Updated on 2024.08.31

# %%
import os
import torch

GPUID = 0
DEVICE = torch.device("cuda:" + str(GPUID))
print("Execution device: ", DEVICE)
print("PyTorch version: ", torch.__version__)
print("CUDA available: ", torch.cuda.is_available())
print("CUDA version: ", torch.version.cuda)
print("CUDA device: ", torch.cuda.get_device_name(GPUID))

work_dir = "H:\workspace\ptyrad" # The main "ptyrad" package is expected to be under this "work_dir"
os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# Out:
# Execution device:  cuda:0
# PyTorch version:  2.4.0
# CUDA available:  True
# CUDA version:  12.1
# CUDA device:  Quadro P5000
# Current working dir:  H:\workspace\ptyrad

# %%
from ptyrad.data_io import load_params
from ptyrad.reconstruction import PtyRADSolver

params_path = "params/demo/tBL_WSe2_1probe_1obj_1slice.yml"

params = load_params(params_path)
ptycho_solver = PtyRADSolver(params, device=DEVICE)
# Out:
# ### Loading params file ###
# Success! .yml file path = params/demo/tBL_WSe2_1probe_1obj_1slice.yml
#
# ### Initializing Initializer ###
#
# ### Initializing cache ###
# use_cached_obj   = False
# use_cached_probe = False
# use_cached_pos   = False
#
# ### Initializing exp_params ###
# Input values are displayed below:
# kv: 80
# conv_angle: 24.9
# Npix: 128
# dx_spec: 0.1494
# defocus: 0
# c3: 0
# z_distance: 2
# Nlayer: 6
# N_scans: 16384
# N_scan_slow: 128
# N_scan_fast: 128
# scan_step_size: 0.429
# scan_flipT: None
# scan_affine: None
# scan_rand_std: 0.15
# omode_max: 4
# omode_init_occu: {'occu_type': 'uniform', 'init_occu': None}
# pmode_max: 2
# pmode_init_pows: [0.02]
# probe_permute: None
# meas_permute: None
# meas_reshape: None
# meas_flipT: [1, 0, 0]
# meas_crop: None
# meas_resample: None
# meas_add_source_size: None
# meas_add_detector_blur: None
# meas_add_poisson_noise: None
# probe_simu_params: None
#
# Derived values given input exp_params:
# kv          = 80 kV
# wavelength  = 0.0418 Ang
# conv_angle  = 24.9 mrad
# Npix        = 128 px
# dk          = 0.0523 Ang^-1
# kMax        = 3.3467 Ang^-1
# alpha_max   = 139.7495 mrad
# dx          = 0.1494 Ang, Nyquist-limited dmin = 2*dx = 0.2988 Ang
# Rayleigh-limited resolution  = 1.0230 Ang (0.61*lambda/alpha for focused probe )
# Real space probe extent = 19.1232 Ang
#
# ### Initializing measurements from 'hdf5' ###
# Success! .hdf5 file path = data/tBL_WSe2/Fig_1h_24.9mrad_Themis/1/data_roi1_Ndp128_step128_dp.hdf5
# Imported .hdf5 data shape = (16384, 128, 128)
# Imported meausrements shape = (16384, 128, 128)
# Imported meausrements int. statistics (min, mean, max) = (-0.2045, 12.0179, 658.5550)
# Flipping measurements with [flipup, fliplr, transpose] = [1, 0, 0]
# Minimum value of -0.2045 subtracted due to the positive px value constraint of measurements
# Normalizing measurements so the averaged measurement has max intensity at 1
# Radius of bright field disk             (rbf) = 11.0 px, suggested probe_mask_k radius (rbf*2/Npix) > 0.17
# meausrements int. statistics (min, mean, max) = (0.0000, 0.0275, 1.4818)
# measurements                      (N, Ky, Kx) = float32, (16384, 128, 128)
#
# ### Initializing probe from 'simu' ###
# Use exp_params and default values instead for simulation
# Start simulating STEM probe
# kv          = 80 kV
# wavelength  = 0.0418 Ang
# conv_angle  = 24.9 mrad
# Npix        = 128 px
# dk          = 0.0523 Ang^-1
# kMax        = 3.3467 Ang^-1
# alpha_max   = 139.7447 mrad
# dx          = 0.1494 Ang, Nyquist-limited dmin = 2*dx = 0.2988 Ang
# Rayleigh-limited resolution  = 1.0229 Ang (0.61*lambda/alpha for focused probe )
# Real space probe extent = 19.1232 Ang
# Start making mixed-state STEM probe with 2 incoherent probe modes
# Relative power of probe modes = [0.98 0.02]
# probe                         (pmode, Ny, Nx) = complex64, (2, 128, 128)
# sum(|probe_data|**2) = 450.45, while sum(meas)/len(meas) = 450.45
#
# ### Initializing probe pos from 'simu' ###
# Simulating probe positions with dx_spec = 0.1494, scan_step_size = 0.429, N_scan_fast = 128, N_scan_slow = 128
# Applying Gaussian distributed random displacement with std = 0.15 px to scan positions
# crop_pos                                (N,2) = int16, (16384, 2)
# crop_pos 1st and last px coords (y,x)         = ([50, 50], [415, 414])
# crop_pos extent (Ang)                         = [54.6804 54.6804]
# probe_pos_shifts                        (N,2) = float32, (16384, 2)
#
# ### Initializing obj from 'simu' ###
# obj_shape is not provided, use exp_params, position range, and probe shape for estimated obj_shape (omode, Nz, Ny, Nx)
# object                    (omode, Nz, Ny, Nx) = complex64, (4, 6, 592, 592)
# object extent                 (Z, Y, X) (Ang) = [12.     88.4448 88.4448]
#
# ### Initializing omode_occu from 'uniform' ###
# omode_occu                            (omode) = float32, (4,)
#
# ### Initializing H (Fresnel propagator) ###
# Calculating H with probe_shape = [128 128], z_distance = 2.0000 Ang, lambd = 0.0418 Ang, extent = [19.1232 19.1232] Ang
# H                                    (Ky, Kx) = complex64, (128, 128)
#
# ### Initializing obj tilts from = 'simu' ###
# Initialized obj_tilts with init_tilts = [[0, 0]] (theta_y, theta_x) mrad
# obj_tilts                              (N, 2) = float32, (1, 2)
#
# ### Checking consistency between input params with the initialized variables ###
# Npix, DP measurements, probe, and H shapes are consistent as '128'
# N_scans, len(meas), N_scan_slow*N_scan_fast, len(crop_pos), and len(probe_pos_shifts) are consistent as '16384'
# obj.shape[0] is consistent with len(omode_occu) as '4'
# obj.shape[1] is consistent with Nlayer as '6'
# obj_tilts is consistent with either 1 or N_scans
# Pass the consistency check of initialized variables, initialization is done!
#
# ### Initializing loss function ###
#
# ### Initializing constraint function ###
#
# ### Done initializing PtyRADSolver ###

# %%
ptycho_solver.run()
# Out:
# ### Starting the PtyRADSolver in reconstruct mode ###
#
# ### PtychoAD optimizable variables ###
# obja            : torch.Size([4, 6, 592, 592])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# objp            : torch.Size([4, 6, 592, 592])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# obj_tilts       : torch.Size([1, 2])              , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# probe           : torch.Size([2, 128, 128])       , torch.complex64 , device:cuda:0, grad:True , lr:1e-04
# probe_pos_shifts: torch.Size([16384, 2])          , torch.float32   , device:cuda:0, grad:True , lr:5e-04
#
# ### Optimizable variables statitsics ###
# Total measurement values:    268,435,456
# Total optimizing variables:  16,887,808
# Overdetermined ratio:        15.90
#
# ### Model behavior ###
# Obj preblur       : False
# Tilt propagator   : False
# Sub-px probe shift: True
# Detector blur     : False
#
# ### Generating indices, batches, and output_path ###
# d90 = 21.000 px or 3.137 Ang
# Selecting indices with the 'center' mode
# Subscan params are not provided, setting subscans to default as half of the total scan for both directions
# Choosing subscan with (64, 64)
# Generated 128 'random' groups of ~32 scan positions in 0.001 sec
# output_path = 'output/tBL-WSe2_test//20240901_center_N4096_dp128_flipT100_random32_p2_4obj_6slice_dz2_plr1e-4_oalr5e-4_oplr5e-4_slr5e-4_tlr0_opos_sng1.0_spr0.1' is generated!
# Successfully copy 'tBL_WSe2_1probe_1obj_1slice.yml' to 'output/tBL-WSe2_test//20240901_center_N4096_dp128_flipT100_random32_p2_4obj_6slice_dz2_plr1e-4_oalr5e-4_oplr5e-4_slr5e-4_tlr0_opos_sng1.0_spr0.1'
#
# ### Start the PtyRAD iterative ptycho reconstruction ###
# Done batch 1 in 0.125 sec
# Done batch 26 in 0.117 sec
# Done batch 51 in 0.117 sec
# Done batch 77 in 0.116 sec
# Done batch 102 in 0.117 sec
# Done batch 128 in 0.116 sec
# Apply fix probe int constraint at iter 1, probe int sum = 450.4548
# Apply hard positivity constraint on objp at iter 1
# Iter: 1, Total Loss: 0.5805, loss_single: 0.5798, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0007, loss_simlar: 0.0000, in 0.0 min 15.017701 sec
#
# Done batch 1 in 0.116 sec
# Done batch 26 in 0.117 sec
# Done batch 51 in 0.117 sec
# Done batch 77 in 0.116 sec
# Done batch 102 in 0.117 sec
# Done batch 128 in 0.117 sec
# Apply fix probe int constraint at iter 2, probe int sum = 450.4549
# Apply hard positivity constraint on objp at iter 2
# Iter: 2, Total Loss: 0.3385, loss_single: 0.3377, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 15.016953 sec
#
# Done batch 1 in 0.117 sec
# Done batch 26 in 0.116 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.117 sec
# Done batch 102 in 0.117 sec
# Done batch 128 in 0.117 sec
# Apply fix probe int constraint at iter 3, probe int sum = 450.4549
# Apply hard positivity constraint on objp at iter 3
# Iter: 3, Total Loss: 0.2724, loss_single: 0.2715, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 15.006937 sec
#
# Done batch 1 in 0.115 sec
# Done batch 26 in 0.117 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.117 sec
# Done batch 102 in 0.116 sec
# Done batch 128 in 0.120 sec
# Apply fix probe int constraint at iter 4, probe int sum = 450.4549
# Apply hard positivity constraint on objp at iter 4
# Iter: 4, Total Loss: 0.2593, loss_single: 0.2584, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 15.007241 sec
#
# Done batch 1 in 0.119 sec
# Done batch 26 in 0.116 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.117 sec
# Done batch 102 in 0.115 sec
# Done batch 128 in 0.116 sec
# Apply fix probe int constraint at iter 5, probe int sum = 450.4548
# Apply hard positivity constraint on objp at iter 5
# Iter: 5, Total Loss: 0.2545, loss_single: 0.2535, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 15.014680 sec
#
# Done batch 1 in 0.116 sec
# Done batch 26 in 0.115 sec
# Done batch 51 in 0.117 sec
# Done batch 77 in 0.115 sec
# Done batch 102 in 0.119 sec
# Done batch 128 in 0.118 sec
# Apply fix probe int constraint at iter 6, probe int sum = 450.4549
# Apply hard positivity constraint on objp at iter 6
# Iter: 6, Total Loss: 0.2519, loss_single: 0.2510, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 15.023737 sec
#
# Done batch 1 in 0.116 sec
# Done batch 26 in 0.116 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.116 sec
# Done batch 102 in 0.116 sec
# Done batch 128 in 0.116 sec
# Apply fix probe int constraint at iter 7, probe int sum = 450.4548
# Apply hard positivity constraint on objp at iter 7
# Iter: 7, Total Loss: 0.2503, loss_single: 0.2493, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 14.990301 sec
#
# Done batch 1 in 0.117 sec
# Done batch 26 in 0.117 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.116 sec
# Done batch 102 in 0.116 sec
# Done batch 128 in 0.115 sec
# Apply fix probe int constraint at iter 8, probe int sum = 450.4550
# Apply hard positivity constraint on objp at iter 8
# Iter: 8, Total Loss: 0.2490, loss_single: 0.2481, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0009, loss_simlar: 0.0000, in 0.0 min 14.988214 sec
#
# Done batch 1 in 0.115 sec
# Done batch 26 in 0.117 sec
# Done batch 51 in 0.116 sec
# Done batch 77 in 0.117 sec
# Done batch 102 in 0.118 sec
# Done batch 128 in 0.116 sec
# Apply fix probe int constraint at iter 9, probe int sum = 450.4548
# Apply hard positivity constraint on objp at iter 9
# Iter: 9, Total Loss: 0.2481, loss_single: 0.2472, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0010, loss_simlar: 0.0000, in 0.0 min 15.017656 sec
#
# Done batch 1 in 0.115 sec
# Done batch 26 in 0.116 sec
# Done batch 51 in 0.117 sec
# Done batch 77 in 0.116 sec
# Done batch 102 in 0.116 sec
# Done batch 128 in 0.118 sec
# Apply fix probe int constraint at iter 10, probe int sum = 450.4549
# Apply hard positivity constraint on objp at iter 10
# Iter: 10, Total Loss: 0.2474, loss_single: 0.2464, loss_poissn: 0.0000, loss_pacbed: 0.0000, loss_sparse: 0.0010, loss_simlar: 0.0000, in 0.0 min 14.999365 sec
#
# Saving summary figures for iter 10
#
# ### The PtyRADSolver is finished in 156.297 sec ###
